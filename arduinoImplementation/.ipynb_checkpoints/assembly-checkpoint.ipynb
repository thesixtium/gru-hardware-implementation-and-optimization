# %%
import re
import sys
from collections import Counter

def count_instructions(filepath):
    # Matches a disassembly line like:
    #   "  e4:  11 24       eor  r1, r1"
    # Captures the mnemonic (first word after the hex bytes column)
    pattern = re.compile(
        r"^\s+"          # leading whitespace
        r"[0-9a-f]+:"    # address + colon
        r"\s+"           # whitespace
        r"(?:[0-9a-f]{2} )+"  # one or more hex byte pairs  e.g. "11 24 "
        r"\s*"           # optional extra whitespace
        r"([a-z]+)"      # MNEMONIC  <-- captured group 1
    )

    counts = Counter()
    total  = 0

    with open(filepath, "r", errors="replace") as fh:
        for line in fh:
            m = pattern.match(line)
            if m:
                mnemonic = m.group(1)
                counts[mnemonic] += 1
                total += 1

    return counts, total


def main():
    filepath = "assembly.txt"
    counts, total = count_instructions(filepath)
    print(counts)
    print(total)

    print(f"{'Instruction':<12} {'Count':>8}  {'% of total':>10}")
    print("-" * 34)
    for mnemonic, count in counts.most_common():
        pct = 100.0 * count / total if total else 0
        print(f"{mnemonic:<12} {count:>8}  {pct:>9.2f}%")
    print("-" * 34)
    print(f"{'TOTAL':<12} {total:>8}")


if __name__ == "__main__":
    main()
# Out:
# Counter({'adc': 2311, 'ldd': 1820, 'ldi': 1771, 'add': 817, 'call': 706, 'std': 662, 'sbci': 523, 'subi': 506, 'movw': 412, 'ror': 351, 'cpc': 314, 'sbc': 210, 'jmp': 207, 'brne': 144, 'ld': 144, 'dec': 141, 'asr': 117, 'cp': 102, 'st': 100, 'adiw': 91, 'sbiw': 88, 'brge': 71, 'sts': 62, 'lds': 60, 'sub': 43, 'mov': 39, 'brlt': 37, 'ori': 23, 'rjmp': 17, 'out': 13, 'ret': 11, 'push': 11, 'cpi': 9, 'pop': 9, 'in': 8, 'eor': 4, 'mul': 4, 'cli': 2, 'elpm': 1, 'brcc': 1, 'reti': 1, 'sei': 1, 'or': 1, 'and': 1, 'brpl': 1, 'sbrs': 1})
# 11968
# Instruction     Count  % of total
# ----------------------------------
# adc              2311      19.31%
# ldd              1820      15.21%
# ldi              1771      14.80%
# add               817       6.83%
# call              706       5.90%
# std               662       5.53%
# sbci              523       4.37%
# subi              506       4.23%
# movw              412       3.44%
# ror               351       2.93%
# cpc               314       2.62%
# sbc               210       1.75%
# jmp               207       1.73%
# brne              144       1.20%
# ld                144       1.20%
# dec               141       1.18%
# asr               117       0.98%
# cp                102       0.85%
# st                100       0.84%
# adiw               91       0.76%
# sbiw               88       0.74%
# brge               71       0.59%
# sts                62       0.52%
# lds                60       0.50%
# sub                43       0.36%
# mov                39       0.33%
# brlt               37       0.31%
# ori                23       0.19%
# rjmp               17       0.14%
# out                13       0.11%
# ret                11       0.09%
# push               11       0.09%
# cpi                 9       0.08%
# pop                 9       0.08%
# in                  8       0.07%
# eor                 4       0.03%
# mul                 4       0.03%
# cli                 2       0.02%
# elpm                1       0.01%
# brcc                1       0.01%
# reti                1       0.01%
# sei                 1       0.01%
# or                  1       0.01%
# and                 1       0.01%
# brpl                1       0.01%
# sbrs                1       0.01%
# ----------------------------------
# TOTAL           11968

# %%
def stats( name, f, w, total=11968):
    instructions_per_second = f
    seconds_to_do = total / instructions_per_second
    max_frequency = 1 / seconds_to_do 
    return name, max_frequency,  w * seconds_to_do

# %%
data = [
    stats("Arduino Mega", 16000000, 0.27),
    stats("Arduino Due", 84000000, 0.26),
    stats("Arduino Nano", 16000000, 0.05),
    stats("ARM Cortex-M4F", 180000000, 0.01),
    stats("STM32 Nucleo-WB55", 64000000, 0.1)
]

# %%
all_stats
# Out:
# [('Arduino Mega', 1336.8983957219252, 0.00020196),
#  ('Arduino Due', 7018.716577540106, 3.704380952380953e-05),
#  ('Arduino Nano', 1336.8983957219252, 3.74e-05),
#  ('ARM Cortex-M4F', 15040.106951871658, 6.648888888888889e-07),
#  ('STM32 Nucleo-WB55', 5347.593582887701, 1.87e-05)]

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %%
labels = [d[0] for d in data]
x_vals = [d[1] for d in data]
y_vals = [d[2] for d in data]

fig, ax = plt.subplots(figsize=(10, 7))

colors = ['#e63946', '#457b9d', '#2a9d8f', '#e9c46a', '#f4a261']
for i, (label, x, y) in enumerate(zip(labels, x_vals, y_vals)):
    ax.scatter(x, y, color=colors[i], s=120, zorder=5, edgecolors='white', linewidths=1.5)
    ax.annotate(label, xy=(x, y), xytext=(8, 6), textcoords='offset points',
                fontsize=9.5, fontweight='bold', color=colors[i])

ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel('Maximum Step Frequency (Hz)', fontsize=12)
ax.set_ylabel('Energy per Step (J)', fontsize=12)
ax.set_title('Microcontroller Performance vs Energy Consumption', fontsize=14, fontweight='bold')
ax.xaxis.set_major_formatter(ticker.FuncFormatter(lambda v, _: f'{v:,.0f}'))
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda v, _: f'{v:.2e}'))
ax.grid(True, which='both', linestyle='--', linewidth=0.5, alpha=0.6)

plt.tight_layout()
plt.show()
